# %%
#Dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint

# %%
#list of tv show titles to query
tv_shows = ["Altered Carbon", "Grey's Anatomy", "This is Us", "The Flash", "Vikings", "Shameless", "Arrow", "Peaky Blinders", "Dirk Gently"]

# make iterative requests to TVmaze search endpoint
url = 'http://api.tvmaze.com/search/shows?q='

pprint(requests.get(url + tv_shows[0]).json()[0]['show']['rating']['average'])


ratings = []

for show in tv_shows:
    ratings.append(requests.get(url + show).json()[0]['show']['rating']['average'])
# Out:
# 8.2

# %%
# create dataframe

df = pd.DataFrame({'TV Show' : tv_shows,
                   'Rating' : ratings
})

df = df.set_index('TV Show')

# %%
# use matplotlib to create a bar chart from the dataframe

ax = df.plot(kind = 'bar', rot = 45, legend = False, figsize = (10, 10), y = 'Rating')

ax.set_ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')
