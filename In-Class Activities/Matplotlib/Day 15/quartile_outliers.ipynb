# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
from stats import median
import numpy as np

# %%
### Data Points
arr = np.array([2.3, 10.2,11.2, 12.3, 14.5, 14.6, 15.0, 15.1, 19.0, 24.0])
arr
# Out:
# array([ 2.3, 10.2, 11.2, 12.3, 14.5, 14.6, 15. , 15.1, 19. , 24. ])

# %%
# Find the median
mid = median(arr)
mid
# Out:
# 14.55

# %%
# Use numpy to create quartiles
q1 = np.percentile(arr, 25)
q3 = np.percentile(arr, 75)
# Out:
# Q1 is 11.474999999999998, Q3 is 15.075

# %%
# Print the quartiles
print(f'Q1 is {q1}, Q3 is {q3}')
# Out:
# Q1 is 11.474999999999998, Q3 is 15.075

# %%
# Calculate the interquartile range
iqr = q3 - q1

print(f'IQR: {iqr}')
# Out:
# IQR: 3.6000000000000014

# %%
# Find lower boundary
# Q1 - 1.5 * IQR

lower_boundary = q1 - 1.5 * iqr
lower_boundary
# Out:
# 6.074999999999996

# %%
# Find upper boundary
# Q3 + 1.5 * IQR

upper_boundary = q3 + 1.5 * iqr
upper_boundary
# Out:
# 20.475

# %%
# Check for any lower outliers

arr[arr<=lower_boundary]
# Out:
# array([2.3])

# %%
# Check for any upper outliers

arr[arr>=upper_boundary]
# Out:
# array([24.])

# %%
# Create box plot

plt.boxplot(arr, showmeans=True)
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
